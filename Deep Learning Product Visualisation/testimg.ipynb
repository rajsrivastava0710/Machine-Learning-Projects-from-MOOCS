# %%
import graphlab

# %%
url='E:\Datset ofr FY Project\Category and Attribute Prediction Benchmark-20171223T092747Z-001\img-002\img'
data = graphlab.image_analysis.load_images(url)
data['label']='Above_Average_Linen_Tee'

# %%
graphlab.canvas.set_target('ipynb')
data.show()
data
# Out:
# Columns:
# 	path	str
# 	image	Image
# 	label	str
#
# Rows: 43
#
# Data:
# +-------------------------------+------------------------+
# |              path             |         image          |
# +-------------------------------+------------------------+
# | E:/Datset ofr FY Project/C... | Height: 300 Width: 300 |
# | E:/Datset ofr FY Project/C... | Height: 300 Width: 205 |
# | E:/Datset ofr FY Project/C... | Height: 300 Width: 207 |
# | E:/Datset ofr FY Project/C... | Height: 301 Width: 199 |
# | E:/Datset ofr FY Project/C... | Height: 300 Width: 247 |
# | E:/Datset ofr FY Project/C... | Height: 301 Width: 199 |
# | E:/Datset ofr FY Project/C... | Height: 300 Width: 205 |
# | E:/Datset ofr FY Project/C... | Height: 300 Width: 300 |
# | E:/Datset ofr FY Project/C... | Height: 300 Width: 205 |
# | E:/Datset ofr FY Project/C... | Height: 301 Width: 199 |
# +-------------------------------+------------------------+
# +-------------------------+
# |          label          |
# +-------------------------+
# | Above_Average_Linen_Tee |
# | Above_Average_Linen_Tee |
# | Above_Average_Linen_Tee |
# | Above_Average_Linen_Tee |
# | Above_Average_Linen_Tee |
# | Above_Average_Linen_Tee |
# | Above_Average_Linen_Tee |
# | Above_Average_Linen_Tee |
# | Above_Average_Linen_Tee |
# | Above_Average_Linen_Tee |
# +-------------------------+
# [43 rows x 3 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %%
url2='E:\Datset ofr FY Project\Category and Attribute Prediction Benchmark-20171223T092747Z-001\img-002\img2'
data2 = graphlab.image_analysis.load_images(url)
data2['label']='Abstract_Diamond_Fringe_Kimono'

# %%
graphlab.canvas.set_target('ipynb')
data2.show()
data2
# Out:
# Columns:
# 	path	str
# 	image	Image
# 	label	str
#
# Rows: 43
#
# Data:
# +-------------------------------+------------------------+
# |              path             |         image          |
# +-------------------------------+------------------------+
# | E:/Datset ofr FY Project/C... | Height: 301 Width: 227 |
# | E:/Datset ofr FY Project/C... | Height: 300 Width: 192 |
# | E:/Datset ofr FY Project/C... | Height: 301 Width: 199 |
# | E:/Datset ofr FY Project/C... | Height: 300 Width: 205 |
# | E:/Datset ofr FY Project/C... | Height: 300 Width: 210 |
# | E:/Datset ofr FY Project/C... | Height: 301 Width: 199 |
# | E:/Datset ofr FY Project/C... | Height: 301 Width: 199 |
# | E:/Datset ofr FY Project/C... | Height: 300 Width: 205 |
# | E:/Datset ofr FY Project/C... | Height: 300 Width: 300 |
# | E:/Datset ofr FY Project/C... | Height: 300 Width: 205 |
# +-------------------------------+------------------------+
# +--------------------------------+
# |             label              |
# +--------------------------------+
# | Abstract_Diamond_Fringe_Kimono |
# | Abstract_Diamond_Fringe_Kimono |
# | Abstract_Diamond_Fringe_Kimono |
# | Abstract_Diamond_Fringe_Kimono |
# | Abstract_Diamond_Fringe_Kimono |
# | Abstract_Diamond_Fringe_Kimono |
# | Abstract_Diamond_Fringe_Kimono |
# | Abstract_Diamond_Fringe_Kimono |
# | Abstract_Diamond_Fringe_Kimono |
# | Abstract_Diamond_Fringe_Kimono |
# +--------------------------------+
# [43 rows x 3 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %%
data,data2
# Out:
# (Columns:
#  	path	str
#  	image	Image
#  	label	str
#
#  Rows: 43
#
#  Data:
#  +-------------------------------+------------------------+
#  |              path             |         image          |
#  +-------------------------------+------------------------+
#  | E:/Datset ofr FY Project/C... | Height: 300 Width: 300 |
#  | E:/Datset ofr FY Project/C... | Height: 300 Width: 205 |
#  | E:/Datset ofr FY Project/C... | Height: 300 Width: 207 |
#  | E:/Datset ofr FY Project/C... | Height: 301 Width: 199 |
#  | E:/Datset ofr FY Project/C... | Height: 300 Width: 247 |
#  | E:/Datset ofr FY Project/C... | Height: 301 Width: 199 |
#  | E:/Datset ofr FY Project/C... | Height: 300 Width: 205 |
#  | E:/Datset ofr FY Project/C... | Height: 300 Width: 300 |
#  | E:/Datset ofr FY Project/C... | Height: 300 Width: 205 |
#  | E:/Datset ofr FY Project/C... | Height: 301 Width: 199 |
#  +-------------------------------+------------------------+
#  +-------------------------+
#  |          label          |
#  +-------------------------+
#  | Above_Average_Linen_Tee |
#  | Above_Average_Linen_Tee |
#  | Above_Average_Linen_Tee |
#  | Above_Average_Linen_Tee |
#  | Above_Average_Linen_Tee |
#  | Above_Average_Linen_Tee |
#  | Above_Average_Linen_Tee |
#  | Above_Average_Linen_Tee |
#  | Above_Average_Linen_Tee |
#  | Above_Average_Linen_Tee |
#  +-------------------------+
#  [43 rows x 3 columns]
#  Note: Only the head of the SFrame is printed.
#  You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.,
#  Columns:
#  	path	str
#  	image	Image
#  	label	str
#
#  Rows: 43
#
#  Data:
#  +-------------------------------+------------------------+
#  |              path             |         image          |
#  +-------------------------------+------------------------+
#  | E:/Datset ofr FY Project/C... | Height: 301 Width: 227 |
#  | E:/Datset ofr FY Project/C... | Height: 300 Width: 192 |
#  | E:/Datset ofr FY Project/C... | Height: 301 Width: 199 |
#  | E:/Datset ofr FY Project/C... | Height: 300 Width: 205 |
#  | E:/Datset ofr FY Project/C... | Height: 300 Width: 210 |
#  | E:/Datset ofr FY Project/C... | Height: 301 Width: 199 |
#  | E:/Datset ofr FY Project/C... | Height: 301 Width: 199 |
#  | E:/Datset ofr FY Project/C... | Height: 300 Width: 205 |
#  | E:/Datset ofr FY Project/C... | Height: 300 Width: 300 |
#  | E:/Datset ofr FY Project/C... | Height: 300 Width: 205 |
#  +-------------------------------+------------------------+
#  +--------------------------------+
#  |             label              |
#  +--------------------------------+
#  | Abstract_Diamond_Fringe_Kimono |
#  | Abstract_Diamond_Fringe_Kimono |
#  | Abstract_Diamond_Fringe_Kimono |
#  | Abstract_Diamond_Fringe_Kimono |
#  | Abstract_Diamond_Fringe_Kimono |
#  | Abstract_Diamond_Fringe_Kimono |
#  | Abstract_Diamond_Fringe_Kimono |
#  | Abstract_Diamond_Fringe_Kimono |
#  | Abstract_Diamond_Fringe_Kimono |
#  | Abstract_Diamond_Fringe_Kimono |
#  +--------------------------------+
#  [43 rows x 3 columns]
#  Note: Only the head of the SFrame is printed.
#  You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.)

# %%
data = data.append(data2)

# %%
graphlab.canvas.set_target('browser')
data.show()
data['feature']=''
data
# Out:
# Canvas is updated and available in a tab in the default browser.
# Columns:
# 	path	str
# 	image	Image
# 	label	str
# 	feature	str
#
# Rows: 86
#
# Data:
# +-------------------------------+------------------------+
# |              path             |         image          |
# +-------------------------------+------------------------+
# | E:/Datset ofr FY Project/C... | Height: 300 Width: 300 |
# | E:/Datset ofr FY Project/C... | Height: 300 Width: 205 |
# | E:/Datset ofr FY Project/C... | Height: 300 Width: 207 |
# | E:/Datset ofr FY Project/C... | Height: 301 Width: 199 |
# | E:/Datset ofr FY Project/C... | Height: 300 Width: 247 |
# | E:/Datset ofr FY Project/C... | Height: 301 Width: 199 |
# | E:/Datset ofr FY Project/C... | Height: 300 Width: 205 |
# | E:/Datset ofr FY Project/C... | Height: 300 Width: 300 |
# | E:/Datset ofr FY Project/C... | Height: 300 Width: 205 |
# | E:/Datset ofr FY Project/C... | Height: 301 Width: 199 |
# +-------------------------------+------------------------+
# +-------------------------+---------+
# |          label          | feature |
# +-------------------------+---------+
# | Above_Average_Linen_Tee |         |
# | Above_Average_Linen_Tee |         |
# | Above_Average_Linen_Tee |         |
# | Above_Average_Linen_Tee |         |
# | Above_Average_Linen_Tee |         |
# | Above_Average_Linen_Tee |         |
# | Above_Average_Linen_Tee |         |
# | Above_Average_Linen_Tee |         |
# | Above_Average_Linen_Tee |         |
# | Above_Average_Linen_Tee |         |
# +-------------------------+---------+
# [86 rows x 4 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %%
graphlab.toolkits.feature_engineering.DeepFeatureExtractor(data['image'], model='auto', output_column_prefix=None)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-153-47c446907f60> in <module>()
# ----> 1 graphlab.toolkits.feature_engineering.DeepFeatureExtractor(data['image'], model='auto', output_column_prefix=None)
#
# C:\Users\Akshat\Anaconda2\envs\gl-env\lib\site-packages\graphlab\toolkits\feature_engineering\_deep_feature_extractor.pyc in __init__(self, features, model, output_column_prefix)
#     139         ----------
#     140         """
# --> 141         _raise_error_if_not_of_type(features, [str, list, type(None)])
#     142         _raise_error_if_not_of_type(model, [str, _NeuralNetClassifier])
#     143         _raise_error_if_not_of_type(output_column_prefix, [str, type(None)])
#
# C:\Users\Akshat\Anaconda2\envs\gl-env\lib\site-packages\graphlab\util\type_checks.pyc in _raise_error_if_not_of_type(arg, expected_type, arg_name)
#      29     err_msg += "(not %s)." % type(arg).__name__
#      30     if not any(map(lambda x: isinstance(arg, x), lst_expected_type)):
# ---> 31         raise TypeError(err_msg)
#      32
#      33 def _raise_error_if_not_function(arg, arg_name=None):
#
# TypeError: Argument must be of type str or list or NoneType (not SArray).
